# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
from math import sqrt
# %matplotlib inline

# %% [markdown]
# Для задания я выбрал распределение Максвелла. Сравним графики нормального распределения и распределения Максвелла.

# %%
mu = 15
sigma = 15
normal = sts.norm(loc = mu, scale = sigma)
maxwell = sts.maxwell(loc = mu, scale = sigma)

x1 = np.linspace(-50, 80, 1000)
pdf1 = normal.pdf(x1)

x2 = np.linspace(-50, 80, 1000)
pdf2 = maxwell.pdf(x2)

plt.plot(x1, pdf1, label = 'norm')
plt.plot(x2, pdf2, label = 'maxwell')
plt.ylabel('pdf')
plt.xlabel('x')
plt.legend()
plt.show()

# %% [markdown]
# Построим гистограмму распределение выборочного среднего для выборки размера 5 в сравнении с нормальным

# %%
#MAXWELL 5


mu = 15
sigma = 15
n = 5
maxwell = sts.maxwell(loc = mu, scale = sigma)
maxwell_hist = [maxwell.rvs(n).mean() for x in range(1000)]
plt.hist(maxwell_hist, density =True , alpha = 0.5, color = 'r', label = 'Sample_hist')

x_maxwell = np.linspace((maxwell.expect()-4*sqrt(maxwell.std())), (maxwell.expect()+4*sqrt(maxwell.std())), 1000)
maxwell_norm = sts.norm(maxwell.expect(), sqrt(maxwell.std()/n))
pdf_maxwell = maxwell_norm.pdf(x_maxwell)
plt.plot(x_maxwell, pdf_maxwell, label = 'Norm', color = 'black')
plt.ylabel('pdf')
plt.xlabel('x')
plt.legend()
plt.show()

# %% [markdown]
# Построим гистограмму распределение выборочного среднего для выборки размера 25 в сравнении с нормальным

# %%
#MAXWELL 25


mu = 15
sigma = 15
n = 25
maxwell = sts.maxwell(loc = mu, scale = sigma)
maxwell_hist = [maxwell.rvs(n).mean() for x in range(1000)]
plt.hist(maxwell_hist, density =True , alpha = 0.5, color = 'g', label = 'Hist')

x_maxwell = np.linspace((maxwell.expect()-4*sqrt(maxwell.std())), (maxwell.expect()+4*sqrt(maxwell.std())), 1000)
maxwell_norm = sts.norm(maxwell.expect(), sqrt(maxwell.std()/n))
pdf_maxwell = maxwell_norm.pdf(x_maxwell)
plt.plot(x_maxwell, pdf_maxwell, label = 'Norm', color = 'black')
plt.ylabel('pdf')
plt.xlabel('x')
plt.legend()
plt.show()

# %% [markdown]
# Построим гистограмму распределение выборочного среднего для выборки размера 125 в сравнении с нормальным

# %%
#MAXWELL 125


mu = 15
sigma = 15
n = 125
maxwell = sts.maxwell(loc = mu, scale = sigma)
maxwell_hist = [maxwell.rvs(n).mean() for x in range(1000)]
plt.hist(maxwell_hist, density =True , alpha = 0.5, color = 'b', label = 'Hist')

x_maxwell = np.linspace((maxwell.expect()-4*sqrt(maxwell.std())), (maxwell.expect()+4*sqrt(maxwell.std())), 1000)
maxwell_norm = sts.norm(maxwell.expect(), sqrt(maxwell.std()/n))
pdf_maxwell = maxwell_norm.pdf(x_maxwell)
plt.plot(x_maxwell, pdf_maxwell, label = 'Norm', color = 'black')
plt.ylabel('pdf')
plt.xlabel('x')
plt.legend()
plt.show()

# %% [markdown]
# Построим гистограмму распределение выборочного среднего для выборки размера 625 в сравнении с нормальным

# %%
#MAXWELL


mu = 15
sigma = 15
n = 625
maxwell = sts.maxwell(loc = mu, scale = sigma)
maxwell_hist = [maxwell.rvs(n).mean() for x in range(1000)]
plt.hist(maxwell_hist, density =True , alpha = 0.5, color = 'purple', label = 'Hist')

x_maxwell = np.linspace((maxwell.expect()-4*sqrt(maxwell.std())), (maxwell.expect()+4*sqrt(maxwell.std())), 1000)
maxwell_norm = sts.norm(maxwell.expect(), sqrt(maxwell.std()/n))
pdf_maxwell = maxwell_norm.pdf(x_maxwell)
plt.plot(x_maxwell, pdf_maxwell, label = 'Norm', color = 'black')
plt.ylabel('pdf')
plt.xlabel('x')
plt.legend()
plt.show()
#maxwell.expect()
#sqrt(maxwell.std())

# %% [markdown]
# # Вывод

# %% [markdown]
# Как видно из графиков выше, распределение выборочный средних уменьшается с размером выборки. Что также очевидно из формулы стандарнтой ошибки среднего:

# %% [markdown]
# $$ se = \frac{sd}{\sqrt{n}} $$
